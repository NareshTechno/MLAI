# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#df = pd.read_csv(r"D:\Naresh\Learning\Upgrad\DocumentsUpgrad\Session2+-+Plotting+Distributions\global_sales_data\market_fact.csv")
# reading cryptocurrency files
btc = pd.read_csv(r"D:\Naresh\Learning\Upgrad\DocumentsUpgrad\Session2+-+Plotting+Distributions\crypto_data\bitcoin_price.csv")
ether = pd.read_csv(r"D:\Naresh\Learning\Upgrad\DocumentsUpgrad\Session2+-+Plotting+Distributions\crypto_data\ethereum_price.csv")
ltc = pd.read_csv(r"D:\Naresh\Learning\Upgrad\DocumentsUpgrad\Session2+-+Plotting+Distributions\crypto_data\litecoin_price.csv")
monero = pd.read_csv(r"D:\Naresh\Learning\Upgrad\DocumentsUpgrad\Session2+-+Plotting+Distributions\crypto_data\monero_price.csv")
neo = pd.read_csv(r"D:\Naresh\Learning\Upgrad\DocumentsUpgrad\Session2+-+Plotting+Distributions\crypto_data\neo_price.csv")
quantum = pd.read_csv(r"D:\Naresh\Learning\Upgrad\DocumentsUpgrad\Session2+-+Plotting+Distributions\crypto_data\qtum_price.csv")
ripple = pd.read_csv(r"D:\Naresh\Learning\Upgrad\DocumentsUpgrad\Session2+-+Plotting+Distributions\crypto_data\ripple_price.csv")

# putting a suffix with column names so that joins are easy
btc.columns = btc.columns.map(lambda x: str(x) + '_btc')
ether.columns = ether.columns.map(lambda x: str(x) + '_et')
ltc.columns = ltc.columns.map(lambda x: str(x) + '_ltc')
monero.columns = monero.columns.map(lambda x: str(x) + '_mon')
neo.columns = neo.columns.map(lambda x: str(x) + '_neo')
quantum.columns = quantum.columns.map(lambda x: str(x) + '_qt')
ripple.columns = ripple.columns.map(lambda x: str(x) + '_rip')

# merging all the files by date
m1 = pd.merge(btc, ether, how="inner", left_on="Date_btc", right_on="Date_et")
m2 = pd.merge(m1, ltc, how="inner", left_on="Date_btc", right_on="Date_ltc")
m3 = pd.merge(m2, monero, how="inner", left_on="Date_btc", right_on="Date_mon")
m4 = pd.merge(m3, neo, how="inner", left_on="Date_btc", right_on="Date_neo")
m5 = pd.merge(m4, quantum, how="inner", left_on="Date_btc", right_on="Date_qt")
crypto = pd.merge(m5, ripple, how="inner", left_on="Date_btc", right_on="Date_rip")
#m2.head()

#crypto.head()
# Subsetting only the closing prices column for plotting
curr = crypto[["Close_btc", "Close_et", 'Close_ltc', "Close_mon", "Close_neo", "Close_qt"]]
curr.head()

# pairplot
sns.pairplot(curr)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
qnt = pd.read_csv(r"D:\Naresh\Learning\Upgrad\DocumentsUpgrad\Session2+-+Plotting+Distributions\crypto_data\QUANTITIES1.csv")
prc = pd.read_csv(r"D:\Naresh\Learning\Upgrad\DocumentsUpgrad\Session2+-+Plotting+Distributions\crypto_data\PRICES.csv")

#prc.head()
#qnt.head()
m1 = pd.merge(prc,qnt, how="inner")#,left_on="PRODUCT", right_on="CATEGORY")

m2 = pd.merge(qnt,prc, how="inner")#,left_on="PRODUCT", right_on="CATEGORY")


print(m1)
print('\n')
print(m2
# Out:
#    QUANTITY    PRODUCT CATEGORY  PRICE
# 0        45   Potatoes      Veg      3
# 1        63  Avocadoes    Fruit      4
# 2        19      Kiwis    Fruit      2
